# %%
import requests
import pandas as pd
from tqdm import tqdm
import sqlite3
import os
import json
from multiprocessing.pool import ThreadPool

# %%
url = "https://api.statbank.dk/v1/subjects"
payload = {
   "recursive": True,
   "includeTables": True,
   "format": "JSON"
}

subs = requests.post(url, payload).json()

# %%
def transformer(s):
    s = s.subjects.apply(pd.Series)
    s.columns = [str(x) for x in s.columns]
    return s


df = (
    pd.DataFrame(subs)
    .drop(
        columns=[
            "tables",
            "hasSubjects"
        ]
    )
    .explode("subjects")
    .rename(
        columns={
            "id": "lvl1_id",
            "description": "lvl1_desc",
            "active": "lvl1_active"
        }
    )
    .pipe(
        lambda df:
            df.assign(**df.subjects.apply(pd.Series))
    )
    .drop(
        columns=[ 
            "hasSubjects",
            "tables"
        ]
    )
    .rename(
        columns={
            "id": "lvl2_id",
            "description": "lvl2_desc",
            "active": "lvl2_active"
        }
    )
    .explode("subjects")
    .pipe(
        lambda df:
            df.assign(**df.pipe(transformer))
    )
    .drop(
        columns=[ 
            "hasSubjects",
            "0",
            "subjects"
        ]
    )
    .explode("tables")
    .query("tables.notna()")
    .rename(
        columns={
            "id": "lvl3_id",
            "description": "lvl3_desc",
            "active": "lvl3_active"
        }
    )
    .pipe(
        lambda df:
            df.assign(**df.tables.apply(pd.Series))
    )
    .drop(
        columns=[
            "tables"
        ]
    )
    .rename(
        columns={
            "id": "tableid",
            "text": "tablename"
        }
    )
)

metadata_cols = [
    'lvl1_id',      'lvl1_desc',    'lvl1_active', 
    'lvl2_id',      'lvl2_desc',    'lvl2_active',  
    'lvl3_id',      'lvl3_desc',    'lvl3_active', 
    'tableid'
]

metadata = df[metadata_cols]
tables = df.drop(columns=metadata_cols[:-1] + ["variables"])
variables = df[["tableid", "firstPeriod", "latestPeriod", "updated", "active", "variables"]].explode("variables")

tables.set_index("tableid", inplace=True)

# %%
conn = sqlite3.connect("dst.db")
metadata.to_sql("metadata", conn, if_exists="replace")
tables.to_sql("tables", conn, if_exists="replace")
variables.to_sql("variables", conn, if_exists="replace")
conn.close()

# %%
db_name = "dst.db"
conn = sqlite3.connect(db_name, check_same_thread=False)
cursor = conn.cursor()

query = """
DROP TABLE IF EXISTS tblinfo_json;
CREATE TABLE tblinfo_json (
    tbl_name VARCHAR(20),
    json_data BLOB
);
"""

cursor.executescript(query)


url_tblinfo    = "https://api.statbank.dk/v1/tableinfo"

def get_data(tbl, cursor=cursor):
    payload_tblinfo = {
        "table": tbl,
        "format": "JSON"
    }
    tblinfo = requests.post(url_tblinfo, payload_tblinfo).json()
    tblinfo = json.dumps(tblinfo)
    tblinfo = bytes(tblinfo, "utf-8")
    try:
        lock.acquire(True)
        cursor.execute('INSERT INTO tblinfo_json (tbl_name, json_data) VALUES(?, ?)', (tbl, tblinfo,))
        # print(f"Executed task for {tbl}")
        conn.commit()
    finally:
        lock.release()
    pbar.update(1)

lock = threading.Lock()
    
data = tables.index
pbar = tqdm(total=len(data))
pool = ThreadPool(processes=4)
pool.map(get_data, data)
pool.close()
pool.join()
pbar.close()
cursor.close()
conn.close()
# Out:
#   8%|█████████████                                                                                                                                                       | 401/5041 [00:49<32:41,  2.36it/s]
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /var/folders/jl/zt_f3_ys4_v66l0xf3s8__q40000gn/T/ipykernel_8468/3066429330.py in <module>
#      32 pbar = tqdm(total=len(data))
#      33 pool = ThreadPool(processes=8)
# ---> 34 pool.map(get_data, data)
#      35 pool.close()
#      36 pool.join()
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     769             return self._value
#     770         else:
# --> 771             raise self._value
#     772
#     773     def _set(self, i, obj):
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123         job, i, func, args, kwds = task
#     124         try:
# --> 125             result = (True, func(*args, **kwds))
#     126         except Exception as e:
#     127             if wrap_exception and func is not _helper_reraises_exception:
#
# ~/opt/anaconda3/lib/python3.8/multiprocessing/pool.py in mapstar(args)
#      46
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#      49
#      50 def starmapstar(args):
#
# /var/folders/jl/zt_f3_ys4_v66l0xf3s8__q40000gn/T/ipykernel_8468/3066429330.py in get_data(tbl, cursor)
#      24     tblinfo = json.dumps(tblinfo)
#      25     tblinfo = bytes(tblinfo, "utf-8")
# ---> 26     cursor.execute('INSERT INTO tblinfo_json (tbl_name, json_data) VALUES(?, ?)', (tbl, tblinfo,))
#      27     # print(f"Executed task for {tbl}")
#      28     conn.commit()
#
# ProgrammingError: Recursive use of cursors not allowed.
